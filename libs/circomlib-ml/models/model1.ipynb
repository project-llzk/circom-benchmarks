# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import Model
import numpy as np

# %%
inputs = Input(shape=(3,))
x = Dense(2, activation='relu')(inputs)
outputs = Dense(1)(x)
model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 3)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11 (44.00 B)
#  Trainable params: 11 (44.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.weights
# Out:
# [<Variable path=dense/kernel, shape=(3, 2), dtype=float32, value=[[-0.6637713  -0.05156314]
#   [-0.7439218   0.40865397]
#   [ 0.41671586 -0.29590154]]>,
#  <Variable path=dense/bias, shape=(2,), dtype=float32, value=[0. 0.]>,
#  <Variable path=dense_1/kernel, shape=(2, 1), dtype=float32, value=[[-0.70173454]
#   [-1.1945624 ]]>,
#  <Variable path=dense_1/bias, shape=(1,), dtype=float32, value=[0.]>]

# %%
X = np.random.rand(1,3)
X
# Out:
# array([[0.76760228, 0.28501713, 0.16283743]])

# %%
y = model.predict(X)
y
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# array([[-0.03429535]], dtype=float32)

# %%
in_json = {
    "in": (X[0]*1000).round().astype(int).astype(str).tolist(),
    "Dense32weights": (model.weights[0].numpy()*1000).round().astype(int).astype(str).tolist(),
    "Dense21weights": (model.weights[2].numpy()*1000).round().astype(int).astype(str).tolist()
}

# %%
out_json = {
    "out": (y*(1000**3)).round().astype(int).flatten().tolist()
}

# %%
import json

# %%
with open("model1_input.json", "w") as f:
    json.dump(in_json, f)

# %%
with open("model1_output.json", "w") as f:
    json.dump(out_json, f)
