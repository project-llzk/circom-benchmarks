# %%
from tensorflow.keras.layers import Input, AveragePooling2D, Lambda
from tensorflow.keras import Model
import numpy as np

# %%
inputs = Input(shape=(5,5,3))
x = AveragePooling2D(pool_size=2)(inputs)
x = Lambda(lambda x: x*4)(x)
model = Model(inputs, x)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 5, 5, 3)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 2, 2, 3)        │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda_1 (Lambda)               │ (None, 2, 2, 3)        │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
X = np.random.rand(1,5,5,3)
X
# Out:
# array([[[[7.56859981e-01, 6.07854888e-01, 5.98500542e-01],
#          [3.81973283e-01, 9.30729258e-01, 1.09027524e-01],
#          [6.88598062e-01, 2.12084337e-02, 4.06854131e-01],
#          [6.51581328e-01, 2.82638262e-02, 8.26466355e-02],
#          [2.18526921e-01, 5.79075593e-02, 3.48719182e-01]],
#
#         [[6.04291864e-04, 1.84282171e-01, 4.14111353e-01],
#          [5.84544976e-01, 9.96300010e-02, 2.83472921e-02],
#          [3.66941736e-02, 6.20862787e-01, 4.71307976e-01],
#          [6.77616762e-01, 4.54463159e-01, 9.18811139e-02],
#          [4.50017297e-01, 1.78698714e-01, 8.52089398e-01]],
#
#         [[3.99301214e-01, 1.11914103e-01, 5.14027146e-01],
#          [8.85326924e-01, 9.80215596e-01, 4.47086143e-01],
#          [2.44146918e-01, 6.32512787e-01, 4.97770705e-01],
#          [5.94544988e-01, 4.65702524e-01, 4.03370737e-01],
#          [2.31713158e-01, 2.23924249e-01, 9.69707765e-01]],
#
#         [[6.58074809e-01, 4.34672494e-01, 9.18199709e-01],
#          [5.81625061e-01, 2.38976405e-01, 8.71240754e-01],
#          [2.05309707e-01, 5.24261491e-01, 3.40255065e-01],
#          [6.25163250e-01, 1.74370800e-01, 5.77828964e-01],
#          [5.59658512e-01, 4.10275411e-01, 1.20426885e-01]],
#
#         [[8.18851422e-01, 8.19082976e-01, 2.70566774e-01],
#          [9.98254730e-02, 6.28281485e-01, 8.38764694e-01],
#          [5.66336523e-01, 8.80203304e-01, 2.84812737e-01],
#          [9.09497274e-01, 9.07519436e-01, 6.75767720e-01],
#          [1.76208518e-01, 6.41787062e-01, 3.92136817e-01]]]])

# %%
y = model.predict(X)
y
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# array([[[[1.7239826, 1.8224964, 1.1499866],
#          [2.0544903, 1.1247982, 1.0526899]],
#
#         [[2.524328 , 1.7657785, 2.7505536],
#          [1.6691649, 1.7968476, 1.8192253]]]], dtype=float32)

# %%
in_json = {
    "in": (X[0]*1000).round().astype(int).astype(str).tolist()
}

# %%
out_json = {
    "out": (y*1000).round().astype(int).flatten().tolist()
}

# %%
import json

# %%
with open("sumPooling2D_input.json", "w") as f:
    json.dump(in_json, f)

# %%
with open("sumPooling2D_output.json", "w") as f:
    json.dump(out_json, f)

# %%
inputs = Input(shape=(10,10,3))
x = AveragePooling2D(pool_size=2, strides=3)(inputs)
x = Lambda(lambda x: x*4)(x)
model = Model(inputs, x)

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 10, 10, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 3, 3, 3)        │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda_2 (Lambda)               │ (None, 3, 3, 3)        │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
X = np.random.rand(1,10,10,3)
X
# Out:
# array([[[[2.79724263e-01, 8.58411003e-01, 9.36710306e-01],
#          [6.72252443e-01, 8.49333388e-01, 3.70626959e-01],
#          [4.86068126e-01, 1.64181480e-01, 7.80743693e-01],
#          [7.75254647e-02, 6.77539934e-02, 3.29565285e-01],
#          [2.60070148e-02, 4.88792139e-01, 7.35326948e-01],
#          [8.01538479e-01, 5.71942216e-01, 8.45028042e-01],
#          [3.96191742e-01, 6.19138116e-01, 7.62540093e-01],
#          [3.40249410e-01, 6.32196337e-01, 4.19859121e-01],
#          [6.56412532e-01, 9.08078215e-01, 4.84166987e-01],
#          [3.13367431e-01, 4.13795977e-01, 4.15987710e-01],
#          [4.58840202e-01, 1.14979468e-01, 3.14164902e-01],
#          [3.81553122e-01, 8.94723916e-01, 6.19831160e-01],
#          [4.31665801e-01, 5.96448137e-01, 4.03033151e-01],
#          [8.25128525e-01, 8.45974385e-01, 9.23180805e-01],
#          [4.26327595e-01, 9.09266598e-02, 8.57788406e-02],
#          [7.63388465e-01, 2.61907348e-01, 5.68481807e-01]],
#
#         [[8.06304980e-01, 8.21217271e-01, 2.84441571e-01],
#          [9.33615038e-01, 4.74056265e-01, 3.94095059e-02],
#          [2.15876322e-01, 9.37966149e-02, 2.06978357e-01],
#          [1.75059976e-01, 8.51261252e-01, 7.03651807e-01],
#          [1.63754441e-01, 8.29620392e-01, 8.42793072e-01],
#          [7.33248012e-01, 7.72801358e-01, 2.48074318e-01],
#          [9.24738779e-01, 6.39121947e-01, 5.53730511e-01],
#          [1.82681483e-01, 3.62465725e-02, 9.07402394e-02],
#          [6.46568354e-01, 9.68554813e-01, 1.32305334e-01],
#          [4.57437109e-01, 4.76180451e-01, 8.41142443e-01]],
#
#         [[6.80156301e-02, 3.15715308e-01, 7.26719094e-02],
#          [7.99570774e-01, 6.13644073e-01, 2.75153854e-01],
#          [3.68063125e-01, 5.87825497e-01, 5.08913563e-01],
#          [3.84810651e-01, 7.93448248e-02, 3.97245132e-01],
#          [4.41613529e-01, 1.00288588e-01, 1.69535255e-01],
#          [1.42164879e-01, 1.81733223e-01, 5.75461259e-01],
#          [1.14899708e-01, 9.89701744e-01, 1.16193416e-01],
#          [3.93703021e-01, 2.53885917e-01, 8.83688401e-04],
#          [7.84876981e-01, 6.01564162e-01, 8.50981771e-02],
#          [7.72331138e-01, 3.58713523e-02, 4.87770692e-01]],
#
#         [[3.16768631e-01, 1.77611847e-01, 3.92595830e-01],
#          [2.65438574e-01, 3.48640375e-01, 6.91830536e-01],
#          [3.08475998e-01, 7.03295263e-01, 4.69338190e-01],
#          [7.85278704e-01, 6.96903073e-01, 8.70530006e-02],
#          [4.01898161e-01, 3.51395171e-01, 4.84799641e-01],
#          [4.26798318e-01, 3.50765455e-01, 8.79240166e-01],
#          [4.49972685e-01, 9.48628788e-02, 8.11052315e-01],
#          [4.28967648e-02, 6.60389798e-03, 1.28814938e-01],
#          [1.78933179e-01, 7.82755215e-02, 6.73688340e-02],
#          [2.15799742e-01, 8.24220523e-01, 3.30488329e-01]]]])

# %%
y = model.predict(X)
y
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# array([[[[1.5148902 , 2.4131536 , 1.8894473 ],
#          [1.2844844 , 1.6627958 , 2.059124  ],
#          [1.1830307 , 3.0445578 , 2.5614443 ]],
#
#         [[2.3535771 , 1.550882  , 2.1520019 ],
#          [0.97868204, 3.431989  , 0.9842633 ],
#          [1.0359821 , 1.5411611 , 1.7671533 ]],
#
#         [[2.5320773 , 2.8959177 , 1.4105129 ],
#          [1.111022  , 2.2096572 , 2.2765975 ],
#          [2.3642147 , 2.117791  , 1.9706846 ]]]], dtype=float32)

# %%
in_json = {
    "in": (X[0]*1000).round().astype(int).astype(str).tolist()
}

# %%
out_json = {
    "out": (y*1000).round().astype(int).astype(str).tolist()
}

# %%
with open("sumPooling2D_stride_input.json", "w") as f:
    json.dump(in_json, f, indent=4)

# %%
with open("sumPooling2D_stride_output.json", "w") as f:
    json.dump(out_json, f, indent=4)
