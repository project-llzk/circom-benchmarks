# %%
from tensorflow.keras.layers import Input, GlobalMaxPooling2D
from tensorflow.keras import Model
import numpy as np

# %%
inputs = Input(shape=(5,5,3))
x = GlobalMaxPooling2D()(inputs)
model = Model(inputs, x)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 5, 5, 3)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d            │ (None, 3)              │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
X = np.random.rand(1,5,5,3)
X
# Out:
# array([[[[0.83332316, 0.83289724, 0.85461029],
#          [0.81470127, 0.06321606, 0.43510897],
#          [0.69088693, 0.35185797, 0.994941  ],
#          [0.92691687, 0.36100146, 0.53897765],
#          [0.97612436, 0.53121514, 0.79727498]],
#
#         [[0.46454869, 0.26785515, 0.60343484],
#          [0.00161451, 0.64417677, 0.37316397],
#          [0.45958601, 0.9945424 , 0.03580853],
#          [0.56563299, 0.0763075 , 0.95313663],
#          [0.23559079, 0.81482963, 0.29092055]],
#
#         [[0.67602101, 0.64977516, 0.39783901],
#          [0.68368415, 0.39429407, 0.8690921 ],
#          [0.43982878, 0.95372641, 0.83187131],
#          [0.86749409, 0.25258705, 0.62881086],
#          [0.04474218, 0.16023208, 0.02243216]],
#
#         [[0.07319465, 0.13752641, 0.60545718],
#          [0.91710226, 0.43448098, 0.39419703],
#          [0.79004502, 0.14867213, 0.24986022],
#          [0.97495978, 0.99270231, 0.71168847],
#          [0.64936284, 0.92022926, 0.68011334]],
#
#         [[0.77048679, 0.74563727, 0.94231253],
#          [0.75336859, 0.6139192 , 0.95273221],
#          [0.41527632, 0.64439844, 0.63697676],
#          [0.63656192, 0.37940336, 0.07965454],
#          [0.06726286, 0.30172462, 0.96830384]]]])

# %%
y = model.predict(X)
y
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# array([[0.97612435, 0.9945424 , 0.994941  ]], dtype=float32)

# %%
in_json = {
    "in": (X[0]*1000).round().astype(int).astype(str).tolist()
}

# %%
out_json = {
    "out": (y*1000).round().astype(int).flatten().tolist()
}

# %%
import json

# %%
with open("globalMaxPooling2D_input.json", "w") as f:
    json.dump(in_json, f)

# %%
with open("globalMaxPooling2D_output.json", "w") as f:
    json.dump(out_json, f)
