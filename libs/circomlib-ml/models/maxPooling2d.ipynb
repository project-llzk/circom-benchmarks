# %%
from tensorflow.keras.layers import Input, MaxPooling2D
from tensorflow.keras import Model
import numpy as np

# %%
inputs = Input(shape=(5,5,3))
x = MaxPooling2D(pool_size=2)(inputs)
model = Model(inputs, x)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 5, 5, 3)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 2, 2, 3)        │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
X = np.random.rand(1,5,5,3)
X
# Out:
# array([[[[0.13321753, 0.97445949, 0.33146142],
#          [0.60294649, 0.61122533, 0.53512476],
#          [0.47907312, 0.69359879, 0.32999213],
#          [0.54536165, 0.78870848, 0.4172727 ],
#          [0.72331264, 0.42963276, 0.49728672]],
#
#         [[0.19436892, 0.76772636, 0.49445903],
#          [0.76657489, 0.95922142, 0.82639391],
#          [0.4623748 , 0.38687326, 0.19470174],
#          [0.2911568 , 0.18411622, 0.75451513],
#          [0.551599  , 0.9332176 , 0.74311063]],
#
#         [[0.32181014, 0.88144079, 0.37834975],
#          [0.74970165, 0.37230795, 0.37070961],
#          [0.01677686, 0.79069027, 0.08021334],
#          [0.28574113, 0.685475  , 0.08186891],
#          [0.53255199, 0.22637009, 0.83859894]],
#
#         [[0.61161142, 0.97869771, 0.37552024],
#          [0.12262857, 0.03362508, 0.14552388],
#          [0.77164048, 0.6711948 , 0.00263185],
#          [0.98245964, 0.56975591, 0.50138517],
#          [0.69547234, 0.3120787 , 0.57266111]],
#
#         [[0.4188474 , 0.04654456, 0.50353378],
#          [0.93898686, 0.94736314, 0.47380062],
#          [0.85295225, 0.27242347, 0.91306722],
#          [0.00924564, 0.60750408, 0.37936417],
#          [0.47900472, 0.89181621, 0.92861913]]]])

# %%
y = model.predict(X)
y
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# array([[[[0.7665749 , 0.97445947, 0.8263939 ],
#          [0.54536164, 0.7887085 , 0.7545151 ]],
#
#         [[0.7497016 , 0.9786977 , 0.37834975],
#          [0.98245966, 0.79069024, 0.50138515]]]], dtype=float32)

# %%
in_json = {
    "in": (X[0]*1000).round().astype(int).astype(str).tolist()
}

# %%
out_json = {
    "out": (y*1000).round().astype(int).flatten().tolist()
}

# %%
import json

# %%
with open("maxPooling2D_input.json", "w") as f:
    json.dump(in_json, f)

# %%
with open("maxPooling2D_output.json", "w") as f:
    json.dump(out_json, f)

# %%
inputs = Input(shape=(10,10,3))
x = MaxPooling2D(pool_size=2, strides=3)(inputs)
model = Model(inputs, x)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 10, 10, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 3, 3, 3)        │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
X = np.random.rand(1,10,10,3)
X
# Out:
# array([[[[0.51672287, 0.73043554, 0.38435166],
#          [0.54077712, 0.52259286, 0.48995291],
#          [0.51015617, 0.90840683, 0.14396171],
#          [0.33097806, 0.6057087 , 0.3560294 ],
#          [0.19378428, 0.75788202, 0.55044338],
#          [0.63740637, 0.52837049, 0.19463607],
#          [0.60984031, 0.13459982, 0.05764127],
#          [0.21393059, 0.45116761, 0.49648125],
#          [0.21199046, 0.91815598, 0.71984819],
#          [0.35010238, 0.9426379 , 0.60981232]],
#
#         [[0.34035698, 0.85418841, 0.14261173],
#          [0.33252601, 0.75466495, 0.40072395],
#          [0.87846621, 0.45469272, 0.49237839],
#          [0.93640143, 0.30651093, 0.12365961],
#          [0.99214004, 0.21715434, 0.92840197],
#          [0.52937847, 0.60851693, 0.97721032],
#          [0.17772131, 0.35071231, 0.53629307],
#          [0.40565698, 0.10065592, 0.94476663],
#          [0.8820701 , 0.52317832, 0.00902416],
#          [0.61591273, 0.13106379, 0.12313185]],
#
#         [[0.08665206, 0.98374697, 0.01302586],
#          [0.36520766, 0.43659634, 0.18024538],
#          [0.82506029, 0.18042618, 0.26241661],
#          [0.32931032, 0.92403616, 0.98703813],
#          [0.56411234, 0.33028878, 0.2909253 ],
#          [0.19564342, 0.90107128, 0.21112268],
#          [0.79996972, 0.0472026 , 0.92965426],
#          [0.22694664, 0.63390638, 0.49221983],
#          [0.9464919 , 0.21445297, 0.04955005],
#          [0.28288476, 0.07969385, 0.56823221]],
#
#         [[0.40175192, 0.6169802 , 0.3888586 ],
#          [0.73487483, 0.79738197, 0.48995208],
#          [0.07355719, 0.53291399, 0.82348648],
#          [0.02190748, 0.81443514, 0.15211931],
#          [0.97061594, 0.67411233, 0.08444658],
#          [0.80918537, 0.75833545, 0.66341565],
#          [0.51992307, 0.71863626, 0.68854955],
#          [0.66385186, 0.42346908, 0.99218345],
#          [0.07973769, 0.85281098, 0.3036929 ],
#          [0.30057231, 0.91525632, 0.15023283]],
#
#         [[0.91563389, 0.19976538, 0.55285761],
#          [0.33860553, 0.1615187 , 0.27828702],
#          [0.26578334, 0.30080714, 0.51697942],
#          [0.28916015, 0.74443455, 0.29502314],
#          [0.57657628, 0.77016436, 0.1430591 ],
#          [0.69614989, 0.07264975, 0.14833524],
#          [0.81302369, 0.77337298, 0.8809635 ],
#          [0.27318871, 0.7442733 , 0.65470377],
#          [0.61969824, 0.10917915, 0.94015729],
#          [0.95790448, 0.35930587, 0.98424756]],
#
#         [[0.38181706, 0.78431435, 0.76045506],
#          [0.22469433, 0.12232071, 0.29492432],
#          [0.57013566, 0.49665706, 0.4065451 ],
#          [0.10572571, 0.13139274, 0.44486896],
#          [0.84202774, 0.28777982, 0.33655177],
#          [0.92318551, 0.89008419, 0.76768269],
#          [0.8595111 , 0.3728458 , 0.53918649],
#          [0.43901531, 0.76621625, 0.65956116],
#          [0.71892556, 0.13147256, 0.14609564],
#          [0.82256112, 0.60181637, 0.94080499]],
#
#         [[0.08944921, 0.98170337, 0.3823734 ],
#          [0.29482402, 0.95263472, 0.40720724],
#          [0.54159697, 0.49502534, 0.9831704 ],
#          [0.06461994, 0.39987113, 0.16937935],
#          [0.14741307, 0.91671453, 0.7786418 ],
#          [0.64500097, 0.9260677 , 0.0356506 ],
#          [0.92247076, 0.85633851, 0.0199941 ],
#          [0.52086139, 0.6669806 , 0.20240228],
#          [0.57330194, 0.64287746, 0.53228353],
#          [0.73018787, 0.10530874, 0.29315723]],
#
#         [[0.62549711, 0.60122247, 0.90769315],
#          [0.80438341, 0.3042356 , 0.99356048],
#          [0.24178823, 0.4126586 , 0.97085465],
#          [0.37785288, 0.78232295, 0.06803886],
#          [0.1913977 , 0.11151682, 0.9064955 ],
#          [0.42402157, 0.100939  , 0.87480922],
#          [0.30986924, 0.68202513, 0.13610858],
#          [0.9916203 , 0.23254897, 0.00531933],
#          [0.39636778, 0.11451362, 0.57042455],
#          [0.4725049 , 0.55720232, 0.9551124 ]],
#
#         [[0.68702759, 0.26099064, 0.69981598],
#          [0.75800421, 0.66097561, 0.02515765],
#          [0.03747027, 0.48949243, 0.34431274],
#          [0.86438758, 0.36335447, 0.76278636],
#          [0.11584334, 0.9896094 , 0.99464094],
#          [0.46136907, 0.8283181 , 0.36802825],
#          [0.68741661, 0.47042051, 0.78852086],
#          [0.86932606, 0.32423824, 0.07845096],
#          [0.04376659, 0.45860688, 0.74295834],
#          [0.710905  , 0.48451896, 0.36314365]],
#
#         [[0.24570277, 0.51478479, 0.86588719],
#          [0.045656  , 0.97915995, 0.70901131],
#          [0.17025465, 0.21588243, 0.87843461],
#          [0.57980821, 0.07231097, 0.39854612],
#          [0.74146603, 0.82670049, 0.31430483],
#          [0.37607202, 0.99537946, 0.5538803 ],
#          [0.75746453, 0.34759901, 0.68016741],
#          [0.2065126 , 0.35141121, 0.70702519],
#          [0.6895189 , 0.61234441, 0.93575674],
#          [0.14025659, 0.53898088, 0.54855502]]]])

# %%
y = model.predict(X)
y
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# array([[[[0.54077715, 0.8541884 , 0.48995292],
#          [0.99214005, 0.757882  , 0.92840195],
#          [0.60984033, 0.4511676 , 0.94476664]],
#
#         [[0.9156339 , 0.79738194, 0.55285764],
#          [0.9706159 , 0.8144351 , 0.29502314],
#          [0.8130237 , 0.773373  , 0.99218345]],
#
#         [[0.8043834 , 0.98170334, 0.9935605 ],
#          [0.3778529 , 0.91671455, 0.9064955 ],
#          [0.9916203 , 0.8563385 , 0.20240228]]]], dtype=float32)

# %%
in_json = {
    "in": (X[0]*1000).round().astype(int).astype(str).tolist()
}

# %%
out_json = {
    "out": (y*1000).round().astype(int).flatten().tolist()
}

# %%
with open("maxPooling2D_stride_input.json", "w") as f:
    json.dump(in_json, f)

# %%
with open("maxPooling2D_stride_output.json", "w") as f:
    json.dump(out_json, f)
