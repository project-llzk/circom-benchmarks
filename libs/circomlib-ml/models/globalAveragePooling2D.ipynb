# %%
from tensorflow.keras.layers import Input, GlobalAveragePooling2D
from tensorflow.keras import Model
import numpy as np

# %%
inputs = Input(shape=(5,5,3))
out = GlobalAveragePooling2D()(inputs)
model = Model(inputs, out)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 5, 5, 3)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 3)              │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
X = np.random.rand(1,5,5,3)
X
# Out:
# array([[[[0.12308506, 0.15495272, 0.05911473],
#          [0.38148862, 0.96601927, 0.51905201],
#          [0.53915332, 0.06860229, 0.66345127],
#          [0.42696411, 0.31178723, 0.76938267],
#          [0.70433771, 0.48241086, 0.01659883]],
#
#         [[0.78348771, 0.03774555, 0.55301027],
#          [0.00617336, 0.9389473 , 0.77203051],
#          [0.21276356, 0.26337045, 0.10642464],
#          [0.39447239, 0.72633949, 0.16639497],
#          [0.13878886, 0.80321752, 0.62645406]],
#
#         [[0.19880688, 0.63312771, 0.61801391],
#          [0.65278276, 0.01987937, 0.54256517],
#          [0.15817386, 0.98271292, 0.98940553],
#          [0.84310276, 0.05917773, 0.67572678],
#          [0.69372236, 0.29156598, 0.91984846]],
#
#         [[0.31396591, 0.97565183, 0.21528348],
#          [0.94000247, 0.13272584, 0.6126267 ],
#          [0.73964691, 0.50683879, 0.50513142],
#          [0.00547989, 0.54678435, 0.83451306],
#          [0.35140487, 0.32798645, 0.3391427 ]],
#
#         [[0.75252746, 0.14371586, 0.8802102 ],
#          [0.57171154, 0.27429843, 0.42133819],
#          [0.72988015, 0.11563112, 0.62892942],
#          [0.17850326, 0.60434683, 0.3019007 ],
#          [0.86320701, 0.50865156, 0.34198403]]]])

# %%
y = model.predict(X)
y
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# array([[0.46814534, 0.43505955, 0.5231414 ]], dtype=float32)

# %%
in_json = {
    "in": (X[0]*1000).round().astype(int).astype(str).tolist()
}

# %%
out_json = {
    "out": (y*1000*100).round().astype(int).flatten().tolist()
}

# %%
import json

# %%
with open("globalAveragePooling2D_input.json", "w") as f:
    json.dump(in_json, f)

# %%
with open("globalAveragePooling2D_output.json", "w") as f:
    json.dump(out_json, f)
