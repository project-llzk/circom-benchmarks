# %%
from tensorflow.keras.layers import Input, BatchNormalization, Dense, Flatten
from tensorflow.keras import Model
import numpy as np

# %%
inputs = Input(shape=(5,5,3))
out = BatchNormalization()(inputs)
out = Flatten()(out)
out = Dense(1)(out)
model = Model(inputs, out)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 5, 5, 3)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 5, 5, 3)        │            12 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 75)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            76 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 88 (352.00 B)
#  Trainable params: 82 (328.00 B)
#  Non-trainable params: 6 (24.00 B)

# %%
X_train = np.random.rand(100,5,5,3)
X_train
# Out:
# array([[[[0.20538619, 0.7611217 , 0.48028893],
#          [0.57289602, 0.60081144, 0.52642062],
#          [0.82991601, 0.52043189, 0.46599433],
#          [0.218208  , 0.03700048, 0.46804102],
#          [0.1134269 , 0.76619146, 0.08603748]],
#
#         [[0.93759517, 0.86403508, 0.72652655],
#          [0.70846444, 0.78656109, 0.1068495 ],
#          [0.76431384, 0.72950923, 0.55485752],
#          [0.09650218, 0.40508184, 0.95150425],
#          [0.91619699, 0.05037141, 0.98855137]],
#
#         [[0.84589627, 0.33664126, 0.62438261],
#          [0.27008007, 0.53272932, 0.20745323],
#          [0.95016958, 0.23735849, 0.90814037],
#          [0.58579276, 0.91551811, 0.9351074 ],
#          [0.53296819, 0.20131612, 0.65120914]],
#
#         [[0.54659155, 0.41902516, 0.7059668 ],
#          [0.56152486, 0.89617051, 0.53151901],
#          [0.25369086, 0.82125897, 0.74435894],
#          [0.38734345, 0.44157449, 0.27752797],
#          [0.9626824 , 0.24955077, 0.89733137]],
#
#         [[0.0279756 , 0.29150671, 0.51464606],
#          [0.75313861, 0.38439607, 0.83683441],
#          [0.37673391, 0.52950346, 0.27970128],
#          [0.92159803, 0.58895661, 0.10202711],
#          [0.9122861 , 0.93377475, 0.86501636]]],
#
#
#        [[[0.75235857, 0.74486097, 0.95105472],
#          [0.07313103, 0.1170478 , 0.22086552],
#          [0.60358362, 0.33925562, 0.08841335],
#          [0.47525009, 0.10692036, 0.21498885],
#          [0.88533168, 0.86499067, 0.83671192]],
#
#         [[0.9979002 , 0.67768034, 0.53642399],
#          [0.95345205, 0.3559112 , 0.28941882],
#          [0.13569024, 0.21872841, 0.45150661],
#          [0.11922641, 0.78890835, 0.70956137],
#          [0.36257695, 0.16730302, 0.45888116]],
#
#         [[0.03629768, 0.44835468, 0.5177429 ],
#          [0.00275664, 0.77659982, 0.64260472],
#          [0.36900476, 0.26804802, 0.55070067],
#          [0.13776998, 0.35110406, 0.41190508],
#          [0.59716143, 0.86341905, 0.31173304]],
#
#         [[0.81794959, 0.6292801 , 0.52538235],
#          [0.71280866, 0.34746073, 0.4927257 ],
#          [0.69760163, 0.03068068, 0.72202481],
#          [0.95446856, 0.36326827, 0.77250126],
#          [0.76365624, 0.24934205, 0.13557005]],
#
#         [[0.78498956, 0.17889362, 0.26158518],
#          [0.97769483, 0.52312625, 0.87261644],
#          [0.24073239, 0.18680629, 0.7506866 ],
#          [0.21049577, 0.0540066 , 0.0279522 ],
#          [0.41369804, 0.86799473, 0.90167569]]],
#
#
#        [[[0.36008746, 0.95296497, 0.02850283],
#          [0.16213765, 0.70430271, 0.78218784],
#          [0.96809955, 0.13757631, 0.23092663],
#          [0.02250879, 0.55268156, 0.81457727],
#          [0.3816562 , 0.55504298, 0.6308083 ]],
#
#         [[0.08674811, 0.01206045, 0.84396383],
#          [0.73602474, 0.62242446, 0.44664529],
#          [0.29776787, 0.29717459, 0.01949818],
#          [0.21889337, 0.28661081, 0.16427564],
#          [0.01276721, 0.48118883, 0.28298186]],
#
#         [[0.88201525, 0.74996204, 0.23382332],
#          [0.67470887, 0.02554208, 0.714144  ],
#          [0.10599983, 0.94212219, 0.75500728],
#          [0.75711968, 0.56113014, 0.00374681],
#          [0.34482736, 0.30567519, 0.23645283]],
#
#         [[0.03032765, 0.34625313, 0.5343476 ],
#          [0.27089587, 0.27011935, 0.04436404],
#          [0.28901863, 0.9517603 , 0.03247413],
#          [0.19961675, 0.15821387, 0.04698047],
#          [0.11765898, 0.15059558, 0.50073909]],
#
#         [[0.76020078, 0.75666767, 0.50622632],
#          [0.54251387, 0.29718807, 0.28019091],
#          [0.73528799, 0.67205104, 0.13785334],
#          [0.46942236, 0.05238976, 0.6219472 ],
#          [0.44976589, 0.92985648, 0.89262406]]],
#
#
#        ...,
#
#
#        [[[0.01151699, 0.52015227, 0.62213977],
#          [0.03838048, 0.97344383, 0.25328294],
#          [0.98683384, 0.50249175, 0.47469532],
#          [0.59288749, 0.13856407, 0.32668431],
#          [0.08162416, 0.37397701, 0.59252662]],
#
#         [[0.2716703 , 0.94439984, 0.92411574],
#          [0.23459961, 0.39915506, 0.0085831 ],
#          [0.17459806, 0.4892599 , 0.08403214],
#          [0.00857307, 0.99069073, 0.65667752],
#          [0.65191205, 0.78035626, 0.9904975 ]],
#
#         [[0.50072028, 0.9286108 , 0.8741126 ],
#          [0.81529   , 0.08735313, 0.75249021],
#          [0.57577295, 0.95300687, 0.1299469 ],
#          [0.55220093, 0.79086184, 0.5538183 ],
#          [0.94118701, 0.08521091, 0.44562286]],
#
#         [[0.82331035, 0.89811757, 0.50968212],
#          [0.67818026, 0.64859996, 0.68463028],
#          [0.53389243, 0.24760588, 0.61674674],
#          [0.64139208, 0.02161906, 0.48760939],
#          [0.23795636, 0.07029695, 0.95180295]],
#
#         [[0.54282108, 0.55485802, 0.1531508 ],
#          [0.87876911, 0.77931891, 0.79638259],
#          [0.36245257, 0.87351072, 0.36571798],
#          [0.67321092, 0.58815585, 0.3716026 ],
#          [0.06774164, 0.92694403, 0.50039188]]],
#
#
#        [[[0.21063145, 0.0875236 , 0.62003368],
#          [0.10213542, 0.69234107, 0.31760787],
#          [0.93311317, 0.85739319, 0.43066385],
#          [0.94536862, 0.78371461, 0.88155906],
#          [0.4417642 , 0.7744412 , 0.7954065 ]],
#
#         [[0.97081977, 0.75239548, 0.91453092],
#          [0.38589196, 0.37020996, 0.34367613],
#          [0.25645053, 0.4790827 , 0.34650182],
#          [0.28509399, 0.41367178, 0.38252515],
#          [0.98130184, 0.95615993, 0.8301774 ]],
#
#         [[0.25965483, 0.40262778, 0.38672095],
#          [0.67519579, 0.64481082, 0.29941485],
#          [0.52718788, 0.06032166, 0.24985076],
#          [0.99644761, 0.94960171, 0.46246538],
#          [0.59278985, 0.32959766, 0.94905994]],
#
#         [[0.66226197, 0.36548369, 0.97895334],
#          [0.90231588, 0.0983714 , 0.16308875],
#          [0.31995683, 0.20307392, 0.66071847],
#          [0.65909076, 0.52827089, 0.87509841],
#          [0.21197193, 0.72709362, 0.53563225]],
#
#         [[0.52380638, 0.17157239, 0.69496389],
#          [0.1762241 , 0.74171299, 0.50047275],
#          [0.24244698, 0.99477072, 0.81742505],
#          [0.20057281, 0.68549807, 0.78434627],
#          [0.16580933, 0.28308693, 0.16036588]]],
#
#
#        [[[0.92828085, 0.21908726, 0.52978967],
#          [0.95802918, 0.76024322, 0.25878332],
#          [0.30616152, 0.91972208, 0.19692591],
#          [0.09609246, 0.42422499, 0.53378095],
#          [0.35589577, 0.50606713, 0.98529341]],
#
#         [[0.89999862, 0.15695017, 0.66861254],
#          [0.2523323 , 0.74299262, 0.30674493],
#          [0.00860995, 0.9499868 , 0.33059732],
#          [0.72645241, 0.55069316, 0.44992086],
#          [0.9953677 , 0.73138865, 0.26817703]],
#
#         [[0.1353211 , 0.14639536, 0.58238136],
#          [0.37375541, 0.38579297, 0.27240394],
#          [0.91593816, 0.24848251, 0.83693535],
#          [0.17822451, 0.86729134, 0.77356574],
#          [0.37703341, 0.55505833, 0.49252103]],
#
#         [[0.21753758, 0.50683289, 0.68694287],
#          [0.90502935, 0.86011363, 0.72193365],
#          [0.55574985, 0.87289178, 0.88758041],
#          [0.5905915 , 0.75099834, 0.24758598],
#          [0.52493642, 0.33260742, 0.93349929]],
#
#         [[0.66919281, 0.40012482, 0.08087264],
#          [0.99263799, 0.99658743, 0.17703028],
#          [0.38871054, 0.97499616, 0.75853555],
#          [0.12004332, 0.6651456 , 0.087895  ],
#          [0.39742671, 0.87814226, 0.4791411 ]]]], shape=(100, 5, 5, 3))

# %%
y_train = np.random.rand(100,1)
y_train
# Out:
# array([[0.96524947],
#        [0.40347659],
#        [0.01739261],
#        [0.23597932],
#        [0.0238418 ],
#        [0.4944914 ],
#        [0.12919981],
#        [0.72459414],
#        [0.57140798],
#        [0.38641192],
#        [0.38616971],
#        [0.11292659],
#        [0.53576623],
#        [0.10908928],
#        [0.47203529],
#        [0.33967134],
#        [0.39765632],
#        [0.13254829],
#        [0.48192292],
#        [0.4834302 ],
#        [0.16986427],
#        [0.3062218 ],
#        [0.62335613],
#        [0.60246801],
#        [0.3241892 ],
#        [0.34497433],
#        [0.36880441],
#        [0.3488615 ],
#        [0.68297575],
#        [0.13552353],
#        [0.59911962],
#        [0.56980462],
#        [0.24588577],
#        [0.19788484],
#        [0.22105095],
#        [0.64502235],
#        [0.72319598],
#        [0.24698173],
#        [0.53698047],
#        [0.63219624],
#        [0.98616886],
#        [0.66606914],
#        [0.16190129],
#        [0.48041986],
#        [0.96262898],
#        [0.12335008],
#        [0.9446989 ],
#        [0.7502219 ],
#        [0.03588679],
#        [0.9770034 ],
#        [0.38181381],
#        [0.09675999],
#        [0.30551563],
#        [0.03953039],
#        [0.41896047],
#        [0.24054223],
#        [0.89127473],
#        [0.05375946],
#        [0.41224967],
#        [0.58569436],
#        [0.96104819],
#        [0.98575305],
#        [0.73149441],
#        [0.57877186],
#        [0.42916084],
#        [0.5752066 ],
#        [0.56499204],
#        [0.3290033 ],
#        [0.19079243],
#        [0.66278008],
#        [0.07476053],
#        [0.79572038],
#        [0.08396174],
#        [0.82684103],
#        [0.38522932],
#        [0.89638657],
#        [0.9246305 ],
#        [0.68419517],
#        [0.42457175],
#        [0.25045388],
#        [0.23203434],
#        [0.77128482],
#        [0.48726221],
#        [0.36650278],
#        [0.29680361],
#        [0.69088897],
#        [0.87740123],
#        [0.37125458],
#        [0.65084062],
#        [0.9730782 ],
#        [0.32360084],
#        [0.95079639],
#        [0.13492045],
#        [0.8478373 ],
#        [0.05362972],
#        [0.29888796],
#        [0.81950564],
#        [0.66660416],
#        [0.45694658],
#        [0.23422795]])

# %%
model.compile("adam", "mse")
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8422
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8147
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7030
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6592
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5806
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5520
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5025
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4410
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3792
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3445

# %%
model.layers[1].weights
# Out:
# [<Variable path=batch_normalization/gamma, shape=(3,), dtype=float32, value=[0.9649134  0.965995   0.96903545]>,
#  <Variable path=batch_normalization/beta, shape=(3,), dtype=float32, value=[ 0.02819148  0.02822662 -0.0283645 ]>,
#  <Variable path=batch_normalization/moving_mean, shape=(3,), dtype=float32, value=[0.16649415 0.16428466 0.16471748]>,
#  <Variable path=batch_normalization/moving_variance, shape=(3,), dtype=float32, value=[0.69657636 0.6970183  0.6959998 ]>]

# %%
X = np.random.rand(1,5,5,3)
X
# Out:
# array([[[[0.31665572, 0.43950441, 0.65549298],
#          [0.84676626, 0.16572574, 0.68151462],
#          [0.93230743, 0.8834265 , 0.97827671],
#          [0.24238576, 0.30127497, 0.50967681],
#          [0.64421205, 0.37446094, 0.32594515]],
#
#         [[0.14402464, 0.92592289, 0.05007417],
#          [0.92258442, 0.00821299, 0.21664579],
#          [0.62039276, 0.97744588, 0.08168193],
#          [0.81472812, 0.91750804, 0.53100617],
#          [0.11430232, 0.04556226, 0.24420875]],
#
#         [[0.31562347, 0.10173635, 0.05634449],
#          [0.8520449 , 0.02009114, 0.95929892],
#          [0.86192614, 0.14130254, 0.88339481],
#          [0.46407096, 0.67250814, 0.15257626],
#          [0.1428145 , 0.07565368, 0.17530209]],
#
#         [[0.97775685, 0.61067272, 0.80623078],
#          [0.35791434, 0.81430926, 0.815033  ],
#          [0.62679939, 0.85284572, 0.04882388],
#          [0.86165372, 0.79805266, 0.82724202],
#          [0.92034413, 0.35331138, 0.27999816]],
#
#         [[0.31997461, 0.17562015, 0.68413053],
#          [0.40332546, 0.99969039, 0.81072121],
#          [0.19705162, 0.79433347, 0.36428114],
#          [0.16482746, 0.5484554 , 0.66761782],
#          [0.00315757, 0.39758931, 0.66262619]]]])

# %%
new_model = Model(inputs, model.layers[1].output)
y = new_model.predict(X)
y
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# array([[[[ 2.0167226e-01,  3.4644195e-01,  5.4128301e-01],
#          [ 8.1410575e-01,  2.9892817e-02,  5.7148659e-01],
#          [ 9.1293085e-01,  8.5971475e-01,  9.1594100e-01],
#          [ 1.1586860e-01,  1.8661794e-01,  3.7203291e-01],
#          [ 5.8009613e-01,  2.7123719e-01,  1.5877393e-01]],
#
#         [[ 2.2325963e-03,  9.0885007e-01, -1.6143203e-01],
#          [ 9.0169799e-01, -1.5222700e-01,  3.1909168e-02],
#          [ 5.5257773e-01,  9.6842217e-01, -1.2474461e-01],
#          [ 7.7709234e-01,  8.9912057e-01,  3.9679006e-01],
#          [-3.2105416e-02, -1.0904293e-01,  6.3901752e-02]],
#
#         [[ 2.0047969e-01, -4.4093169e-02, -1.5415400e-01],
#          [ 8.2020414e-01, -1.3849322e-01,  8.9391327e-01],
#          [ 8.3161986e-01,  1.6541630e-03,  8.0581081e-01],
#          [ 3.7198022e-01,  6.1584616e-01, -4.2456910e-02],
#          [ 8.3453953e-04, -7.4250534e-02, -1.6078845e-02]],
#
#         [[ 9.6543837e-01,  5.4435062e-01,  7.1624577e-01],
#          [ 2.4933809e-01,  7.7979982e-01,  7.2646260e-01],
#          [ 5.5997932e-01,  8.2435656e-01, -1.6288325e-01],
#          [ 8.3130515e-01,  7.6100361e-01,  7.4063373e-01],
#          [ 8.9910972e-01,  2.4678361e-01,  1.0544282e-01]],
#
#         [[ 2.0550653e-01,  4.1332960e-02,  5.7452297e-01],
#          [ 3.0180126e-01,  9.9414170e-01,  7.2145784e-01],
#          [ 6.3494354e-02,  7.5670338e-01,  2.0327085e-01],
#          [ 2.6265964e-02,  4.7241357e-01,  5.5535638e-01],
#          [-1.6051027e-01,  2.9797873e-01,  5.4956269e-01]]]],
#       dtype=float32)

# %%
gamma = model.layers[1].weights[0].numpy()
beta = model.layers[1].weights[1].numpy()
moving_mean = model.layers[1].weights[2].numpy()
moving_var = model.layers[1].weights[3].numpy()
epsilon = model.layers[1].epsilon

# %%
a = gamma/(moving_var+epsilon)**.5
b = beta-gamma*moving_mean/(moving_var+epsilon)**.5

# %%
y-(gamma*(X-moving_mean)/((moving_var+epsilon)**.5)+beta)
# Out:
# array([[[[ 3.20334136e-08,  2.94787872e-08,  2.61280741e-09],
#          [ 7.85178740e-08, -1.31062410e-08,  3.07179433e-08],
#          [-1.64342250e-08,  4.58670858e-08,  3.43876836e-08],
#          [ 2.19613054e-09,  1.98323185e-08,  3.74934843e-08],
#          [ 8.42206309e-08, -1.44759799e-09,  2.66302880e-08]],
#
#         [[-1.98688080e-09,  8.87984919e-08, -9.17446435e-09],
#          [ 6.34634946e-08, -1.99583728e-08,  1.39736544e-08],
#          [-2.80745214e-08,  1.33323888e-07, -7.78392031e-10],
#          [ 1.26147767e-07,  2.48037377e-08,  1.93401656e-09],
#          [-4.39780466e-09, -1.32155878e-08,  1.97457270e-08]],
#
#         [[ 1.54786609e-08, -1.19851679e-08, -2.49014157e-09],
#          [ 8.56376459e-08, -2.25709839e-08, -9.46631729e-09],
#          [ 6.36663061e-08, -6.34963091e-09,  1.06478958e-07],
#          [ 6.91991838e-08,  3.68037262e-08,  7.60792496e-09],
#          [ 1.26307789e-08, -8.82248409e-09,  4.39922183e-09]],
#
#         [[ 6.91087263e-08,  2.73337378e-08,  5.05160975e-08],
#          [ 3.11254649e-08,  4.03820151e-08,  6.73528991e-08],
#          [ 2.02954722e-08,  4.50149287e-08, -9.19641713e-09],
#          [ 8.05404694e-08,  7.53443667e-08,  6.68384980e-08],
#          [-1.59210470e-08,  2.68890842e-08,  7.88142182e-09]],
#
#         [[ 2.18478845e-08, -4.85224783e-09,  9.87573492e-08],
#          [ 2.38487548e-08,  5.65830841e-08,  3.10505379e-08],
#          [ 1.08418775e-08,  5.09184180e-08,  2.70113072e-08],
#          [ 2.77267007e-09,  3.86185187e-08, -3.82615055e-08],
#          [-1.20911203e-08, -8.91395235e-09,  9.83236299e-08]]]])

# %%
y-(a*X+b)
# Out:
# array([[[[ 5.36777740e-08, -3.73838105e-09,  1.89161249e-08],
#          [ 1.20542423e-07, -3.27244243e-08,  4.79527544e-08],
#          [ 2.88789683e-08, -9.40033917e-09,  6.22456520e-08],
#          [ 2.09851699e-08, -6.51879245e-09,  4.85770374e-08],
#          [ 1.18457949e-07, -3.14339626e-08,  3.11368208e-08]],
#
#         [[ 1.30206489e-08,  3.14202093e-08, -1.45432528e-08],
#          [ 1.08402885e-07, -3.17526684e-08,  1.45676107e-08],
#          [ 5.24706034e-09,  7.33863832e-08, -5.01572121e-09],
#          [ 1.66940604e-07, -3.21565670e-08,  1.37810944e-08],
#          [ 9.46704559e-09, -2.68650756e-08,  2.13263515e-08]],
#
#         [[ 3.70833362e-08, -2.84249047e-08, -7.63447205e-09],
#          [ 1.27865133e-07, -3.49552840e-08,  1.77123056e-08],
#          [ 1.06273679e-07, -2.47546781e-08,  1.30940450e-07],
#          [ 9.65109479e-08, -7.98707711e-09,  5.90839200e-09],
#          [ 2.75917844e-08, -2.39666569e-08,  3.51320256e-09]],
#
#         [[ 1.16169230e-07, -1.43856096e-08,  7.22153582e-08],
#          [ 5.43560200e-08, -1.14522558e-08,  8.93672518e-08],
#          [ 5.38633577e-08, -8.73350470e-09, -1.46099621e-08],
#          [ 1.23137369e-07,  2.43175844e-08,  8.92898957e-08],
#          [ 2.89322151e-08, -2.04675060e-09,  1.07431954e-08]],
#
#         [[ 4.36198400e-08, -2.49619005e-08,  1.16085802e-07],
#          [ 4.88251478e-08, -4.45933757e-09,  5.29105422e-08],
#          [ 2.78880383e-08,  7.63732411e-11,  3.28901488e-08],
#          [ 1.85799674e-08, -1.04042330e-11, -2.15241566e-08],
#          [-2.49924850e-09, -4.00491366e-08,  1.14882294e-07]]]])

# %%
a
b
# Out:
# array([-0.1641582 , -0.16172302, -0.21955355], dtype=float32)

# %%
in_json = {
    "in": (X[0]*1000).round().astype(int).astype(str).tolist(),
    "a": (a*1000).round().astype(int).astype(str).tolist(),
    "b": (b*1000*1000).round().astype(int).astype(str).tolist()
}

# %%
out_json = {
    "out": (y*1000000).round().astype(int).flatten().tolist()
}

# %%
import json

# %%
with open("batchNormalization_input.json", "w") as f:
    json.dump(in_json, f)

# %%
with open("batchNormalization_output.json", "w") as f:
    json.dump(out_json, f)

# %%
X.shape
# Out:
# (1, 5, 5, 3)

# %%
a.shape
# Out:
# (3,)

# %%
b.shape
# Out:
# (3,)
